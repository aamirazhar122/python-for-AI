# %%
fav_celebirity = "aamir azhar"
print(fav_celebirity)
# Out:
# aamir azhar

# %%
a = "aamir"
b = "azhar"
c = 23
print(a+ b)
print(type(c))
print(type(a))
# Out:
# aamirazhar
# <class 'int'>
# <class 'str'>

# %%
a = 4.5
print(type(a))
# Out:
# <class 'float'>

# %%
name = "aamir azhar"
print(f"my name is ", name)
# Out:
# my name is  aamir azhar

# %%
first_name = "aamir"
last_name  = "azhar"
print(f"my name is", first_name,last_name)
# Out:
# my name is aamir azhar

# %%
welcome = "welcome to our site"
f_name = "aamir"
l_name = "azhar"
print(f"hello",welcome, f_name, l_name)
# Out:
# hello welcome to our site aamir azhar

# %%
welcome = "welcome to our site"
f_name = "aamir"
l_name = "azhar"

print(f"hello ",welcome, f_name, l_name)
print(f"hello {welcome}")
print(f"hello {f_name}")
# Out:
# hello  welcome to our site aamir azhar
# hello welcome to our site
# hello aamir

# %%
name = "aamir"
number = 99
print(f"{name}")
print(f"my name is ",name)
# Out:
# aamir
# my name is  aamir

# %%
paragraph = """my name ia aamir azhar.\ni am a developer of AI.\nMy aim is to built an AI agency.\nI want to solve problems of people with the use of AI Positively."""
print(paragraph)
# Out:
# my name ia aamir azhar.
# i am a developer of AI.
# My aim is to built an AI agency.
# I want to solve problems of people with the use of AI Positively.

# %%
name = "aamir azhar"
paragraph = f"""my name ia {name}.
i am a developer of AI.
My aim is to built an AI agency.
I want to solve problems of people with the use of AI Positively."""
print(paragraph)
# Out:
# my name ia aamir azhar.
# i am a developer of AI.
# My aim is to built an AI agency.
# I want to solve problems of people with the use of AI Positively.

# %%
a = "aamir"
b = "azhar"
c = 32

print(f"my name is {a} {b}")
print(f"my name is", a, b)
print(f"my age is {c}")
# Out:
# my name is aamir azhar
# my name is aamir azhar
# my age is 32

# %%
a = 10
b = 23
c = a + b
print(c)
print("addition", a + b)
# Out:
# 33
# addition 33

# %%
a = 100
b = 56
c = a - b
print(c)
print("subtraction", a-b)
# Out:
# 44
# subtraction 44

# %%
a = 100
b = 50
c  = a/b
print("divide", a/b)
print(c)
# Out:
# divide 2.0
# 2.0

# %%
a = 10
b = 10
c = a * b
print(c)
print("multiplication", a * b)
# Out:
# 100
# multiplication 100

# %%
a = 24
b = 5
print(a % b)
# Out:
# 4

# %%
a = 10
print(a ** 2) # 10 x 10
print(a ** 3) # 10 x 10 x 10
# Out:
# 100
# 1000

# %%
#Assignment
#Question:
# total members = ?
# amount of Rabri (in grams & KG) per person rabri is 250 grams = ?
faculty_members = 12
admin_staff = 4
students = 100
absent = 15           

Total_members = faculty_members + admin_staff + students
total_present_members = Total_members - absent
print(f"total present members {total_present_members}")

amount_of_Rabri = print(f"Rabri in Grams {total_present_members * 250}")
amount_of_Rabri_in_Kilo_grams = print(f"Rabri in KGs {total_present_members * 250/1000}")
# Out:
# total present members 101
# Rabri in Grams 25250
# Rabri in KGs 25.25
